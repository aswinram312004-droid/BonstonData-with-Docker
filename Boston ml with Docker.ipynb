# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## load the data set

# %%
boston=pd.read_csv("D:\\Data set\\BostonHousing.csv")
boston.keys()

cpy=np.copy(boston)

# %%
boston.keys()
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
# boston is an inbuld 

boston_descr = """
Boston Housing Dataset (Manual Load)

Rows: 506
Features: 13
Target: MEDV

CRIM    - Crime rate
ZN      - Residential land zoned
INDUS   - Non-retail business acres
CHAS    - Charles River dummy
NOX     - Nitric oxides
RM      - Avg rooms
AGE     - Old houses %
DIS     - Distance to jobs
RAD     - Highway access
TAX     - Property tax
PTRATIO - Pupil-teacher ratio
B       - Racial composition (ethical issue)
LSTAT   - Lower status population
"""

print(boston_descr)
# Out:
# Boston Housing Dataset (Manual Load)
#
# Rows: 506
# Features: 13
# Target: MEDV
#
# CRIM    - Crime rate
# ZN      - Residential land zoned
# INDUS   - Non-retail business acres
# CHAS    - Charles River dummy
# NOX     - Nitric oxides
# RM      - Avg rooms
# AGE     - Old houses %
# DIS     - Distance to jobs
# RAD     - Highway access
# TAX     - Property tax
# PTRATIO - Pupil-teacher ratio
# B       - Racial composition (ethical issue)
# LSTAT   - Lower status population

# %%
print(boston_descr)
# Out:
# Boston Housing Dataset (Manual Load)
#
# Rows: 506
# Features: 13
# Target: MEDV
#
# CRIM    - Crime rate
# ZN      - Residential land zoned
# INDUS   - Non-retail business acres
# CHAS    - Charles River dummy
# NOX     - Nitric oxides
# RM      - Avg rooms
# AGE     - Old houses %
# DIS     - Distance to jobs
# RAD     - Highway access
# TAX     - Property tax
# PTRATIO - Pupil-teacher ratio
# B       - Racial composition (ethical issue)
# LSTAT   - Lower status population

# %%
boston.keys()
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %% [markdown]
# ### Preparing the data set

# %%
df=pd.DataFrame(boston)

# %%
df.head(8)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172  96.1  5.9505    5  311     15.2
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2
# 5  394.12   5.21  28.7
# 6  395.60  12.43  22.9
# 7  396.90  19.15  27.1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %% [markdown]
# ### summarizing the status of the data

# %%
df.describe()

# it only work in numerical column not a categorical column
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# ## check the missing values

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %% [markdown]
# ### check the duplicate values
# ### correlation

# %%
x=df.corr()
x
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
x['medv']
# Out:
# crim      -0.388305
# zn         0.360445
# indus     -0.483725
# chas       0.175260
# nox       -0.427321
# rm         0.695360
# age       -0.376955
# dis        0.249929
# rad       -0.381626
# tax       -0.468536
# ptratio   -0.507787
# b          0.333461
# lstat     -0.737663
# medv       1.000000
# Name: medv, dtype: float64

# %%
sns.pairplot(df.corr())

# %%
# GRAPH 1: CRIM vs MEDV (Crime rate vs Price)

plt.scatter(df['crim'],df['medv'])

plt.xlabel("Crime rate")
plt.ylabel("Price")



'''
PRACTICAL WAY (REAL LIFE)
Suppose:

Area A crime = 0.2

Area B crime = 2

Area C crime = 25

Dataset la:

Most areas < 1 irundha →

Area A = very safe

Area B = ok

Area C = unsafe

'''
# Out:
# '\nPRACTICAL WAY (REAL LIFE)\nSuppose:\n\nArea A crime = 0.2\n\nArea B crime = 2\n\nArea C crime = 25\n\nDataset la:\n\nMost areas < 1 irundha →\n\nArea A = very safe\n\nArea B = ok\n\nArea C = unsafe\n\n'

# %%
plt.scatter(df['rm'],df['medv'])

plt.xlabel("Crime rate")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
#### create simple linear regression  line in scatter plot

sns.regplot(x='rm',y='medv',data=df)
# Out:
# <Axes: xlabel='rm', ylabel='medv'>

# %%
sns.regplot(x='lstat',y='medv',data=df)
# Out:
# <Axes: xlabel='lstat', ylabel='medv'>

# %%
sns.regplot(x='chas',y='medv',data=df)
# Out:
# <Axes: xlabel='chas', ylabel='medv'>

# %%
sns.regplot(x='ptratio',y='medv',data=df)
# Out:
# <Axes: xlabel='ptratio', ylabel='medv'>

# %% [markdown]
# ### independent and dependent features

# %%
# df.iloc[rows, columns]
#      : → ella rows (0 to 505)
#      :-1 → last column thavira ella columns


x=df.iloc[:,:-1]
y=df.iloc[:,-1]

"""
X output =  crim   zn   indus   chas   nox   rm   age   dis   rad   tax   ptratio   b   lstat
Y output =
            medv
            22.5
            21.6
            34.7
            33.4
            36.2


"""
# Out:
# '\nX output =  crim   zn   indus   chas   nox   rm   age   dis   rad   tax   ptratio   b   lstat\nY output =\n            medv\n            22.5\n            21.6\n            34.7\n            33.4\n            36.2\n\n\n'

# %%
x.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %% [markdown]
# ### Train,Test  and Split

# %%
from sklearn.model_selection import train_test_split

# X_train + y_train → model learns pattern
'''
X_test → model predicts
y_test → actual answer

random_state=42 ENNA?

Every time run panna,

Train set different result

Test set different result

Result change aagu

Solution:
random_state=42


 Same split every time
 Reproducible results
'''

X_train,x_test,Y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %% [markdown]
# <p>Model X_test paathu predict pannuma illa y_test paathu predict pannuma?
#
# (Answer: X_test)
#
# y_test enna use?
#
# (Answer: compare panna)</p>

# %%
X_train
# Out:
#          crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 5     0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222
# 116   0.13158   0.0  10.01     0  0.547  6.176  72.5  2.7301    6  432
# 45    0.17142   0.0   6.91     0  0.448  5.682  33.8  5.1004    3  233
# 16    1.05393   0.0   8.14     0  0.538  5.935  29.3  4.4986    4  307
# 468  15.57570   0.0  18.10     0  0.580  5.926  71.0  2.9084   24  666
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 106   0.17120   0.0   8.56     0  0.520  5.836  91.9  2.2110    5  384
# 270   0.29916  20.0   6.96     0  0.464  5.856  42.1  4.4290    3  223
# 348   0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 435  11.16040   0.0  18.10     0  0.740  6.629  94.6  2.1247   24  666
# 102   0.22876   0.0   8.56     0  0.520  6.405  85.4  2.7147    5  384
#
#      ptratio       b  lstat
# 5       18.7  394.12   5.21
# 116     17.8  393.30  12.04
# ...

# %%
x_test
# Out:
#         crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 173  0.09178   0.0   4.05     0  0.510  6.416   84.1  2.6463    5  296
# 274  0.05644  40.0   6.41     1  0.447  6.758   32.9  4.0776    4  254
# 491  0.10574   0.0  27.74     0  0.609  5.983   98.8  1.8681    4  711
# 72   0.09164   0.0  10.81     0  0.413  6.065    7.8  5.2873    4  305
# 452  5.09017   0.0  18.10     0  0.713  6.297   91.8  2.3682   24  666
# ..       ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 441  9.72418   0.0  18.10     0  0.740  6.406   97.2  2.0651   24  666
# 23   0.98843   0.0   8.14     0  0.538  5.813  100.0  4.0952    4  307
# 225  0.52693   0.0   6.20     0  0.504  8.725   83.0  2.8944    8  307
# 433  5.58107   0.0  18.10     0  0.713  6.436   87.9  2.3158   24  666
# 447  9.92485   0.0  18.10     0  0.740  6.251   96.6  2.1980   24  666
#
#      ptratio       b  lstat
# 173     16.6  395.50   9.04
# 274     17.6  396.90   3.53
# ...

# %%
Y_train
# Out:
# 5      28.7
# 116    21.2
# 45     19.3
# 16     23.1
# 468    19.1
#        ...
# 106    19.5
# 270    21.1
# 348    24.5
# 435    13.4
# 102    18.6
# Name: medv, Length: 354, dtype: float64

# %%
y_test
# Out:
# 173    23.6
# 274    32.4
# 491    13.6
# 72     22.8
# 452    16.1
#        ...
# 441    17.1
# 23     14.5
# 225    50.0
# 433    14.3
# 447    12.6
# Name: medv, Length: 152, dtype: float64

# %% [markdown]
# ### Standarize the data set

# %% [markdown]
# <div style="font-family: Arial; line-height:1.7;">
#
#   <h2 style="color:#1f4bd8;">📏 STANDARDIZATION NA ENNA?</h2>
#
#   <div style="background:#f3f6ff; padding:14px; border-left:6px solid #1f4bd8; border-radius:6px;">
#     <p><b>Simple meaning:</b></p>
#     <p>
#       👉 <b>Ella features-ai same scale-ku kondu varradhu</b>
#     </p>
#   </div>
#
#   <br>
#
#   <h3 style="color:#1f4bd8;">❓ WHY STANDARDIZATION NEEDED?</h3>
#
#   <p>Un dataset-la features paaru 👇</p>
#
#   <table style="border-collapse:collapse; width:60%;">
#     <tr style="background:#e8edff;">
#       <th style="border:1px solid #ccc; padding:8px;">Feature</th>
#       <th style="border:1px solid #ccc; padding:8px;">Range</th>
#     </tr>
#     <tr>
#       <td style="border:1px solid #ccc; padding:8px;">CRIM</td>
#       <td style="border:1px solid #ccc; padding:8px;">0 to 88</td>
#     </tr>
#     <tr>
#       <td style="border:1px solid #ccc; padding:8px;">RM</td>
#       <td style="border:1px solid #ccc; padding:8px;">3 to 9</td>
#     </tr>
#     <tr>
#       <td style="border:1px solid #ccc; padding:8px;">TAX</td>
#       <td style="border:1px solid #ccc; padding:8px;">187 to 711</td>
#     </tr>
#     <tr>
#       <td style="border:1px solid #ccc; padding:8px;">PTRATIO</td>
#       <td style="border:1px solid #ccc; padding:8px;">12 to 22</td>
#     </tr>
#   </table>
#
#   <br>
#
#   <div style="background:#fff4f4; padding:14px; border-left:6px solid #e53935; border-radius:6px;">
#     <p><b>🚨 Problem:</b></p>
#     <p>
#       👉 Ellam <b>different ranges</b><br>
#       👉 ML model <b>confuse aagum</b>
#     </p>
#   </div>
#
#   <br>
#
#   <h3 style="color:#1f4bd8;">🧠 ML PROBLEM WITHOUT SCALING</h3>
#
#   <ul>
#     <li>TAX values romba <b>perusa</b> irukum</li>
#     <li>CRIM values romba <b>chinna</b> irukum</li>
#   </ul>
#
#   <p>👉 Model think pannum:</p>
#
#   <div style="background:#fff7e6; padding:12px; border-left:6px solid #ff9800; border-radius:6px;">
#     <p><i>“TAX romba important”</i> 😵‍💫</p>
#     <p>(Just because numbers big — not because actual importance)</p>
#   </div>
#
#   <br>
#
#   <h3 style="color:#1f4bd8;">✅ SOLUTION: STANDARDIZATION</h3>
#
#   <p><b>Formula:</b></p>
#
#   <pre style="background:#0f172a; color:#e5e7eb; padding:12px; border-radius:6px;">
# z = (x - mean) / std
#   </pre>
#
#   <ul>
#     <li>👉 Mean becomes <b>0</b></li>
#     <li>👉 Standard Deviation becomes <b>1</b></li>
#   </ul>
#
#   <br>
#
#   <h3 style="color:#1f4bd8;">📊 WHAT STANDARDIZATION DOES?</h3>
#
#   <table style="border-collapse:collapse; width:70%;">
#     <tr style="background:#e8edff;">
#       <th style="border:1px solid #ccc; padding:8px;">Feature</th>
#       <th style="border:1px solid #ccc; padding:8px;">Before</th>
#       <th style="border:1px solid #ccc; padding:8px;">After Scaling</th>
#     </tr>
#     <tr>
#       <td style="border:1px solid #ccc; padding:8px;">CRIM</td>
#       <td style="border:1px solid #ccc; padding:8px;">0.006</td>
#       <td style="border:1px solid #ccc; padding:8px;">-0.7</td>
#     </tr>
#     <tr>
#       <td style="border:1px solid #ccc; padding:8px;">TAX</td>
#       <td style="border:1px solid #ccc; padding:8px;">711</td>
#       <td style="border:1px solid #ccc; padding:8px;">1.2</td>
#     </tr>
#   </table>
#
#   <p>👉 Now all features are on <b>equal footing</b> ⚖️</p>
#
#   <br>
#
#   <h3 style="color:#1f4bd8;">🔹 STEP-BY-STEP CODE (VERY IMPORTANT)</h3>
#
#   <pre style="background:#0f172a; color:#e5e7eb; padding:14px; border-radius:6px;">
# from sklearn.preprocessing import StandardScaler
#
# scaler = StandardScaler()
#
# X_train = scaler.fit_transform(X_train)
# X_test  = scaler.transform(X_test)
#   </pre>
#
#   <br>
#
#   <h3 style="color:#d32f2f;">🧠 WHY <code>fit_transform()</code> ON TRAIN ONLY?</h3>
#   <p><b>MOST IMPORTANT CONCEPT 🔥</b></p>
#
#   <div style="background:#fff4f4; padding:14px; border-left:6px solid #e53935; border-radius:6px;">
#     <ul>
#       <li>❌ Test data-la <b>fit</b> panna koodathu</li>
#       <li>❌ <b>Data Leakage</b> nadakkum</li>
#     </ul>
#   </div>
#
#   <br>
#
#   <div style="background:#e8f5e9; padding:14px; border-left:6px solid #4caf50; border-radius:6px;">
#     <p><b>Correct Logic:</b></p>
#     <ul>
#       <li>Train data → <b>model learning</b></li>
#       <li>Test data → <b>unseen data</b></li>
#     </ul>
#     <p>
#       👉 Test data information <b>train-ku leak aaga koodathu</b>
#     </p>
#   </div>
#
#   <br>
#
#   <div style="background:#f3f6ff; padding:14px; border-left:6px solid #1f4bd8; border-radius:6px;">
#     <p><b>🎯 FINAL INTERVIEW TAKEAWAY</b></p>
#     <p>
#       <i>“Standardization prevents models from giving unfair importance to large-scale features and avoids data leakage when applied correctly.”</i>
#     </p>
#   </div>
#
# </div>

# %% [markdown]
# ##### in more simple  terms
# Salary example
#
# Person A salary = 30,000 (INR)
#
# Person B salary = 2 (Lakh)
#
# so model think person A is high salary compare to person B so model decide A is high so decision is wrong
# thats why we need to standarize the scale
#
#
# Scale = Feature values irukra measurement range
#
# Example:
#
# CRIM scale → 0 to 88
#
# RM scale → 3 to 9
#
# TAX scale → 187 to 711
#
#
# FEATURE NA ENNA?
#
#
# Feature = Oru object-ai describe panna use pannra property
#
# Boston dataset la:
#
# Feature	Meaning
# CRIM	Andha area la crime rate
# RM	Andha area la average rooms
# TAX	Andha area la property tax
# PTRATIO	School quality
#
#  Features = Inputs (X)
#  Model itha use pannithaan predict pannum.

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()

# %%
X_Train=scalar.fit_transform(X_train)

# %%
X_Test=scalar.transform(x_test)

# %%
X_Train
# Out:
# array([[-0.41425879, -0.50512499, -1.29214218, ...,  0.18727079,
#          0.39651419, -1.01531611],
#        [-0.40200818, -0.50512499, -0.16208345, ..., -0.21208981,
#          0.3870674 , -0.05366252],
#        [-0.39721053, -0.50512499, -0.60948856, ..., -0.16771641,
#          0.42854113, -0.31132373],
#        ...,
#        [-0.41604586,  3.03838247, -1.3166773 , ..., -0.56707702,
#          0.35987906, -0.90549329],
#        [ 0.92611293, -0.50512499,  1.00549958, ...,  0.8528718 ,
#         -2.87841346,  1.52750437],
#        [-0.39030549, -0.50512499, -0.37135358, ...,  1.16348561,
#         -3.32828832, -0.25218837]], shape=(354, 13))

# %% [markdown]
# ### Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(X_Train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# <div style="font-family: Arial; line-height:1.7;">
#
#   <h2 style="color:#1f4bd8;">📐 coef_ — CORRECT INTERPRETATION (AFTER STANDARDIZATION)</h2>
#
#   <div style="background:#fff4f4; padding:14px; border-left:6px solid #e53935; border-radius:6px;">
#     <p><b>🚨 IMPORTANT WARNING</b></p>
#     <p>
#       👉 Your data is <b>STANDARDIZED</b><br>
#       👉 So <b>coef_ values are NOT in original units</b>
#     </p>
#   </div>
#
#   <br>
#
#   <h3 style="color:#1f4bd8;">🧠 What coef_ ACTUALLY means here</h3>
#
#   <div style="background:#f3f6ff; padding:14px; border-left:6px solid #1f4bd8; border-radius:6px;">
#     <p>
#       👉 <b>coef_</b> = change in target when<br>
#       👉 feature increases by <b>1 STANDARD DEVIATION</b><br>
#       👉 keeping all other features constant
#     </p>
#   </div>
#
#   <br>
#
#   <h3 style="color:#1f4bd8;">📊 Example Interpretation</h3>
#
#   <table style="border-collapse:collapse; width:85%;">
#     <tr style="background:#e8edff;">
#       <th style="border:1px solid #ccc; padding:8px;">Feature</th>
#       <th style="border:1px solid #ccc; padding:8px;">coef_</th>
#       <th style="border:1px solid #ccc; padding:8px;">Correct Meaning</th>
#     </tr>
#
#     <tr>
#       <td style="border:1px solid #ccc; padding:8px;">CRIM</td>
#       <td style="border:1px solid #ccc; padding:8px; color:#e53935;"><b>-1.10</b></td>
#       <td style="border:1px solid #ccc; padding:8px;">
#         If CRIM increases by <b>1 std</b> → Price decreases by <b>1.10 units</b>
#       </td>
#     </tr>
#
#     <tr>
#       <td style="border:1px solid #ccc; padding:8px;">RM</td>
#       <td style="border:1px solid #ccc; padding:8px; color:#2e7d32;"><b>+2.91</b></td>
#       <td style="border:1px solid #ccc; padding:8px;">
#         If RM increases by <b>1 std</b> → Price increases by <b>2.91 units</b>
#       </td>
#     </tr>
#
#     <tr>
#       <td style="border:1px solid #ccc; padding:8px;">LSTAT</td>
#       <td style="border:1px solid #ccc; padding:8px; color:#e53935;"><b>-2.05</b></td>
#       <td style="border:1px solid #ccc; padding:8px;">
#         If LSTAT increases by <b>1 std</b> → Price decreases by <b>2.05 units</b>
#       </td>
#     </tr>
#   </table>
#
#   <br>
#
#   <h3 style="color:#d32f2f;">🔥 GOLDEN RULE (INTERVIEW READY)</h3>
#
#   <div style="background:#e8f5e9; padding:14px; border-left:6px solid #4caf50; border-radius:6px;">
#     <p>
#       ✔ With standardized data → coef shows <b>relative importance</b><br>
#       ✔ Larger |coef| → stronger influence on target<br>
#       ❌ coef ≠ real-world unit change
#     </p>
#   </div>
#
#   <br>
#
#   <div style="background:#f3f6ff; padding:14px; border-left:6px solid #1f4bd8; border-radius:6px;">
#     <p><b>🎯 FINAL TAKEAWAY</b></p>
#     <p>
#       <i>
#         “After standardization, coefficients represent the effect of a one-standard-deviation change in the feature on the target, not a one-unit change.”
#       </i>
#     </p>
#   </div>
#
# </div>

# %%
# print the coefficient and the intercept
print(regression.coef_)

"""
Positive coefficient (+)
→ feature increase → price increase

Negative coefficient (-)
→ feature increase → price decrease
"""
# Out:
# [-1.10834602  0.80843998  0.34313466  0.81386426 -1.79804295  2.913858
#  -0.29893918 -2.94251148  2.09419303 -1.44706731 -2.05232232  1.02375187
#  -3.88579002]
# '\nPositive coefficient (+)\n→ feature increase → price increase\n\nNegative coefficient (-)\n→ feature increase → price decrease\n'

# %% [markdown]
# # output
# | Feature | Coefficient | Meaning                      |
# | ------- | ----------- | ---------------------------- |
# | CRIM    | -1.108      | Crime ↑ → Price ↓            |
# | ZN      | +0.808      | Residential land ↑ → Price ↑ |
# | INDUS   | +0.343      | Industry ↑ → Price ↑ (small) |
# | CHAS    | +0.813      | River near → Price ↑         |
# | NOX     | -1.798      | Pollution ↑ → Price ↓        |
# | RM      | +2.913      | Rooms ↑ → Price ↑            |
# | AGE     | -0.299      | Old houses ↑ → Price ↓       |
# | DIS     | -2.942      | Distance ↑ → Price ↓         |
# | RAD     | +2.094      | Highway access ↑ → Price ↑   |
# | TAX     | -1.447      | Tax ↑ → Price ↓              |
# | PTRATIO | -2.052      | Students ↑ → Price ↓         |
# | B       | +1.023      | (ethical feature)            |
# | LSTAT   | -3.886      | Poor % ↑ → Price ↓           |

# %%
print(regression.intercept_)
# Out:
# 23.01581920903955

# %%
regression.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'positive': False,
#  'tol': 1e-06}

# %%
reg_predict=regression.predict(X_Test)

# %%
reg_predict
# Out:
# array([28.64896005, 36.49501384, 15.4111932 , 25.40321303, 18.85527988,
#        23.14668944, 17.3921241 , 14.07859899, 23.03692679, 20.59943345,
#        24.82286159, 18.53057049, -6.86543527, 21.80172334, 19.22571177,
#        26.19191985, 20.27733882,  5.61596432, 40.44887974, 17.57695918,
#        27.44319095, 30.1715964 , 10.94055823, 24.02083139, 18.07693812,
#        15.934748  , 23.12614028, 14.56052142, 22.33482544, 19.3257627 ,
#        22.16564973, 25.19476081, 25.31372473, 18.51345025, 16.6223286 ,
#        17.50268505, 30.94992991, 20.19201752, 23.90440431, 24.86975466,
#        13.93767876, 31.82504715, 42.56978796, 17.62323805, 27.01963242,
#        17.19006621, 13.80594006, 26.10356557, 20.31516118, 30.08649576,
#        21.3124053 , 34.15739602, 15.60444981, 26.11247588, 39.31613646,
#        22.99282065, 18.95764781, 33.05555669, 24.85114223, 12.91729352,
#        22.68101452, 30.80336295, 31.63522027, 16.29833689, 21.07379993,
# ...

# %% [markdown]
# ### Assumption

# %%
plt.scatter(y_test,reg_predict)

# %%
# Residuals 
"""
WHY RESIDUAL IMPORTANT?

Residuals use pannradhu:

1️⃣ Model mistake evlo nu paaka
2️⃣ Pattern iruka nu check panna
3️⃣ Linear regression assumptions verify panna
"""

residuals=y_test-reg_predict

# %%
residuals
# Out:
# 173    -5.048960
# 274    -4.095014
# 491    -1.811193
# 72     -2.603213
# 452    -2.755280
#          ...
# 441    -0.303672
# 23      1.114059
# 225    10.016575
# 433    -2.382863
# 447    -5.685618
# Name: medv, Length: 152, dtype: float64

# %% [markdown]
# NEGATIVE RESIDUAL (MOST VALUES)
#
# Example:
#
# 173  -5.04
#
#
# Meaning:
#
# Actual price < Predicted price
#
# Example:
#
# Model predicted = 30
#
# Actual price = 25
#
# Residual:
#
# 25 − 30 = -5
#
#
# 👉 Model jasthi-aa predict panniduchu
# 👉 (Over-prediction)
#
# ✅ POSITIVE RESIDUAL
#
# Example:
#
# 225  10.01
#
#
# Meaning:
#
# Actual price > Predicted price
#
# Example:
#
# Model predicted = 20
#
# Actual price = 30
#
# Residual:
#
# 30 − 20 = +10
#
#
# 👉 Model kammi-aa predict panniduchu
# 👉 (Under-prediction)

# %%
sns.displot(residuals,kind="kde")

# %%
## scatter plot with respoect ot predition and residuals
# uniform distribution

plt.scatter(reg_predict,residuals)

# %% [markdown]
# ## metrics Concept

# %% [markdown]
# ### R2_score to check the relationship between the y_test and  regression prediction

# %%
from sklearn.metrics import r2_score as scr
score=scr(y_test,reg_predict)
print(score)
# Out:
# 0.7112260057484934

# %% [markdown]
# Ne model predict pannita ✔️
#
# <d> Ipa client/company  keakuranga prediction  ok but intha Model average-aa evlo mistake pannuthu?</d>
#
# “Model evlo thappu pannuthu?”
#
# 👉 Athuku answer dhaan
# MAE, MSE, RMSE
#
# | Metric | Focus             |
# | ------ | ----------------- |
# | MAE    | Average mistake   |
# | RMSE   | Big mistakes      |
# | MSE    | Mathematical loss |

# %%
from sklearn.metrics import mean_squared_error as ms
from sklearn.metrics import mean_absolute_error as ma

print("Mean Square error (mse)",ms(y_test,reg_predict))
print("mean Average Error (mae)",ma(y_test,reg_predict))
print("Root Mean Square Error (RMSE)",np.sqrt(ms(y_test,reg_predict)))
# Out:
# Mean Square error (mse) 21.517444231177205
# mean Average Error (mae) 3.1627098714574053
# Root Mean Square Error (RMSE) 4.6386899261728205

# %% [markdown]
# ### R square and adjusted R Square

# %%
1 - (1 - score) * (len(y_test) - 1) / (len(y_test) - X_Test.shape[1] - 1)
# Out:
# 0.6840226584639312

# %% [markdown]
# ### New Data Prediction

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
boston.head(5)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
type(boston)
# Out:
# pandas.core.frame.DataFrame

# %%
boston.iloc[0].values.reshape(1,-1)
# Out:
# array([[6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#         6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#         4.980e+00, 2.400e+01]])

# %%
regression.predict(
    scalar.transform(x.iloc[0].values.reshape(1, -1))
)
# Out:
# C:\Users\ASUS2025\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([30.08649576])

# %% [markdown]
# ### Pickling the model file for deployment

# %%
import pickle as pkl

# %%
pkl.dump(regression,open('regmodel.pkl','wb'))

# %%
pickled_model=pkl.load(open("regmodel.pkl","rb"))

# %%
## prediction 

pickled_model.predict(
    scalar.transform(
        x.iloc[0].values.reshape(1, -1)
    )
)
# Out:
# C:\Users\ASUS2025\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([30.08649576])
